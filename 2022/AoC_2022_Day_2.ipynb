C X
C Z
B Y
C X
C X
C X
A Y
A X
C Z
C Z
C X
C X
B X
B Y
C X
C Y
B Y
B Y
C X
C Z
C X
C Z
B X
C X
C X
B Y
B Y
B Y
C X
C X
C X
C Z
C X
C X
B Z
C X
C Y
C X
A Y
C X
C X
B X
C X
C X
B Z
C X
C X
C Z
C Z
C X
C Y
C X
C X
C X
C X
B Y
C X
C Y
C Z
C X
C X
C X
C X
B Y
B X
C X
C X
C Y
C X
B Y
C X
C X
C Z
C Z
C X"""

# %%
# Rock Paper Scissors 
arrayInput = stringInput.split('\n')
testInput = ['A Y', 'B X', 'C Z'] # this one works!!

myChoices = ['X', 'Y', 'Z']
opponentChoices = ['A', 'B', 'C']

# scoring vars
totalScore = 0
lossPoint = 0
drawPoint = 3
winPoint = 6

for i in arrayInput:
    opponentChoice = i[0]
    myChoice = i[-1]

    # determine my choice and add to total 
    for j in range(len(myChoices)):
        if myChoice == myChoices[j]:
            myTypePoint = j+1
            totalScore += myTypePoint
            
        if opponentChoice == opponentChoices[j]:
            opponentTypePoint = j+1
    
    # determine outcome of battle
    if (myTypePoint, opponentTypePoint) in [(1,3), (2,1), (3,2)]: 
        totalScore += winPoint
        #print("Round score: ", myTypePoint + winPoint)
    elif (myTypePoint, opponentTypePoint) in [(1,2), (2,3), (3,1)]: 
        totalScore += lossPoint
        #print("Round score: ", myTypePoint + lossPoint)
    else:
        totalScore += drawPoint
        # print("Round score: ", myTypePoint + drawPoint)
    
    # debug
    # print("current totalScore: ", totalScore)
    # print("Opponent choice: ", opponentChoice)
    # print("Opponent type point: ", opponentTypePoint)
    # print("My choice:", myChoice)
    # print("My type point: ", myTypePoint)
    # print("\n\n")
    

print("total Points: ", totalScore)
# Out:
# total Points:  14375

# %%
# Part 2: The cheating continues LMAOOO

''' 
X means you need to lose: point = 0
Y means you need to end the round in a draw: point = 3
Z means you need to win: point = 6
'''
arrayInput = stringInput.split('\n')

myOutcomes = [['X', 0], ['Y', 3], ['Z', 6]]
opponentChoices = ['A', 'B', 'C']

rockPoint = 1
paperPoint = 2
scissorPoint = 3
totalScore = 0

for i in arrayInput:
    opponentChoice = i[0]
    myOutcome = i[-1]

    # determine my choice and add to total 
    for j in range(len(myOutcomes)):
        if myOutcome == myOutcomes[j][0]:
            myOutcomeValue = myOutcomes[j][0]
            myOutcomePoint = myOutcomes[j][1]
            totalScore += myOutcomePoint
            
        if opponentChoice == opponentChoices[j]:
            opponentTypePoint = j+1
    
    # determine which move to make based on required outcome
    if (myOutcomeValue, opponentTypePoint) in [('X', 2), ('Y', 1), ('Z', 3)]:
        totalScore += rockPoint
    elif (myOutcomeValue, opponentTypePoint) in [('X', 3), ('Y', 2), ('Z', 1)]:
        totalScore += paperPoint
    else:
        totalScore += scissorPoint

print("totalScore: ", totalScore)
# Out:
# totalScore:  10274
